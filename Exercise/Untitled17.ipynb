# %%
class Student:
    def __init__(self, name, age):
        fname = name.strip()+".txt"
        student_file = open(fname, 'w')
        student_file.write("Name: %s \n" % (name))
        student_file.write("Age: %d \n" % (age))
        student_file.close()
        
        self.student_file = fname
        self.name = name
        self.age = age
        self.total_number_of_units = 0
        
    def collect_raw_scores(self):
        raw_scores = {}
        while True:
            course = input("Enter course or 'quit' to stop:")
            if (course == "quit"): 
                break
            unit_weight = int(input("Enter unit weight of %s "%(course)))
            score = int(input("Enter score for %s: "%(course)))
            raw_scores.update({course: [unit_weight, score]})
        with open(self.student_file, "a") as f:
            f.write("\n")
            print(raw_scores, file=f)
        
        return raw_scores
    
    def points_for_semester(self, semester_scores):
        total_grade_points = 0
        total_units = 0
        for course,weight_and_score in semester_scores.items():
            weight = weight_and_score[0]
            score = weight_and_score[1]
            total_units += weight
            
            if (0 <= score <= 39):
                point = 0 * weight
            elif (40 <= score <= 44):
                point = 1 * weight
            elif (45 <= score <= 49):
                point = 2 * weight
            elif (50 <= score <= 59):
                point = 3 * weight
            elif (60 <= score <= 69):
                point = 4 * weight
            elif (70 <= score <= 100):
                point = 5 * weight
            total_grade_points += point
            
            self.total_number_of_units += total_units
            
        return [total_grade_points, total_units]

if __name__ == "__main__":
    name = input("Enter Student's name: ")
    age = int(input("Enter student's age"))
    
    student = Student(name, age)
    total_points = 0
    total_units = 0
    for i in range(0,6):
        print("Collecting data for Semester '%d':\n"%(i+1))
        semester_scores = student.collect_raw_scores()
        points_per_sem = student.points_for_semester(semester_scores)
        total_points += points_per_sem[0]
        total_units += points_per_sem[1]
    
    print("CGPA for %s is %f" % (student.name, total_points/total_units))
# Out:
# Enter Student's name: Gabriel
# Enter student's age19
# Collecting data for Semester '1':
#
# Enter course or 'quit' to stop:csc201
# Enter unit weight of csc201 3
# Enter score for csc201: 70
# Enter course or 'quit' to stop:cpe203
# Enter unit weight of cpe203 2
# Enter score for cpe203: 70
# Enter course or 'quit' to stop:mth201
# Enter unit weight of mth201 5
# Enter score for mth201: 64
# Enter course or 'quit' to stop:eee201
# Enter unit weight of eee201 2
# Enter score for eee201: 50
# Enter course or 'quit' to stop:mee205
# Enter unit weight of mee205 3
# Enter score for mee205: 60
# Enter course or 'quit' to stop:mee203
# Enter unit weight of mee203 2
# Enter score for mee203: 50
# Enter course or 'quit' to stop:che201
# Enter unit weight of che201 2
# Enter score for che201: 70
# Enter course or 'quit' to stop:ee291
# Enter unit weight of ee291 10
# Enter score for ee291: 50
# Enter course or 'quit' to stop:quit
# Collecting data for Semester '2':
#
# Enter course or 'quit' to stop:csc201
# Enter unit weight of csc201 3
# Enter score for csc201: 60
# Enter course or 'quit' to stop:mth
# Enter unit weight of mth 289738
# Enter score for mth: i38y3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a9bd833921c4> in <module>
#      62     for i in range(0,6):
#      63         print("Collecting data for Semester '%d':\n"%(i+1))
# ---> 64         semester_scores = student.collect_raw_scores()
#      65         points_per_sem = student.points_for_semester(semester_scores)
#      66         total_points += points_per_sem[0]
#
# <ipython-input-1-a9bd833921c4> in collect_raw_scores(self)
#      19                 break
#      20             unit_weight = int(input("Enter unit weight of %s "%(course)))
# ---> 21             score = int(input("Enter score for %s: "%(course)))
#      22             raw_scores.update({course: [unit_weight, score]})
#      23         with open(self.student_file, "a") as f:
#
# ValueError: invalid literal for int() with base 10: 'i38y3'
