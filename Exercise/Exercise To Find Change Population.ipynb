# %%
import matplotlib.pyplot as plt
#to find change in populations
year =[2001,2002,2003,2004,2005]
population=[10,25,28,40,90]
plt.plot(year,population)
plt.xlabel('year')
plt.ylabel('population')
plt.fill_between(year,population,0,color='violet')
plt.title('Change in Population')

plt.show()

# %%
import numpy as np 
x=np.linspace(0,5,10)
y=x**2

plt.figure()# create fugure object
plt.plot(x,y,'b')#
plt.ylabel('y')
plt.xlabel('x')
plt.title('Change in populaton')
plt.show()
